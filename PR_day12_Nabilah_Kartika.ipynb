# %% [markdown]
# # Assignment Day 12 :
# 1. Gunakan data iris.csv : https://drive.google.com/file/d/1j3qxOQxnjVk-wZuRE92J7sRhXeqj_piO/view?usp=sharing
# 2. Jawablah poin-poin assignment yang tertera dibawah

# %%
import pandas as pd
import numpy as np
import scipy
import warnings
warnings.filterwarnings("ignore")

# Plotting Usage
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/iris.csv')
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ## 1. Assignment EDA
# Visualisasi di tiap plot numerik, dan tulis insight yang didapat

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal length (cm)', y='sepal width (cm)')
plt.title('Sebaran Nilai sepal length vs sepal width')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal length (cm)', y='petal length (cm)')
plt.title('Sebaran Nilai sepal length vs petal length')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal length (cm)', y='petal width (cm)')
plt.title('Sebaran Nilai sepal length vs petal width')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal width (cm)', y='petal length (cm)')
plt.title('Sebaran Nilai sepal width vs petal length')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal width (cm)', y='petal width (cm)')
plt.title('Sebaran Nilai sepal width vs petal width')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal width (cm)', y='sepal length (cm)')
plt.title('Sebaran Nilai sepal width vs sepal length')
plt.show()

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Looping untuk kolom 'sepal width' dan 'sepal length'
columns = ['sepal width (cm)', 'sepal length (cm)']

for col in columns:
    # Box plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, data=df)
    plt.title(f'Box Plot - {col}' if col == 'sepal width' else f'Box Plot - {col}')
    plt.xlabel(col)
    plt.ylabel('Nilai')
    plt.show()

# %%
for col in columns:
    # Histogram
    plt.figure(figsize=(12, 6))
    sns.histplot(df[col], bins=30, kde=False)
    plt.title(f'Box Plot - {col}' if col == 'sepal width' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %%
# Looping untuk kolom 'sepal width' dan 'petal width'
columns = ['sepal width (cm)', 'petal width (cm)']

for col in columns:
    # Box plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, data=df)
    plt.title(f'Box Plot - {col}' if col == 'sepal width' else f'Box Plot - {col}')
    plt.xlabel(col)
    plt.ylabel('Nilai')
    plt.show()

# %%
for col in columns:
    # Histogram
    plt.figure(figsize=(12, 6))
    sns.histplot(df[col], bins=30, kde=False)
    plt.title(f'Box Plot - {col}' if col == 'sepal width' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %%
# Looping untuk kolom 'sepal width' dan 'petal length'
columns = ['sepal width (cm)', 'petal length (cm)']

for col in columns:
    # Box plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, data=df)
    plt.title(f'Box Plot - {col}' if col == 'sepal width' else f'Box Plot - {col}')
    plt.xlabel(col)
    plt.ylabel('Nilai')
    plt.show()

# %%
for col in columns:
    # Histogram
    plt.figure(figsize=(12, 6))
    sns.histplot(df[col], bins=30, kde=False)
    plt.title(f'Box Plot - {col}' if col == 'sepal width' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %%
# Looping untuk kolom 'sepal length' dan 'sepal width'
columns = ['sepal length (cm)', 'petal width (cm)']

for col in columns:
    # Box plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, data=df)
    plt.title(f'Box Plot - {col}' if col == 'sepal length' else f'Box Plot - {col}')
    plt.xlabel(col)
    plt.ylabel('Nilai')
    plt.show()

# %%
for col in columns:
    # Histogram
    plt.figure(figsize=(12, 6))
    sns.histplot(df[col], bins=30, kde=False)
    plt.title(f'Box Plot - {col}' if col == 'sepal length' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %%
# Looping untuk kolom 'sepal length' dan 'petal length'
columns = ['sepal length (cm)', 'petal length (cm)']

for col in columns:
    # Box plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, data=df)
    plt.title(f'Box Plot - {col}' if col == 'sepal length' else f'Box Plot - {col}')
    plt.xlabel(col)
    plt.ylabel('Nilai')
    plt.show()

# %%
for col in columns:
    # Histogram
    plt.figure(figsize=(12, 6))
    sns.histplot(df[col], bins=30, kde=False)
    plt.title(f'Box Plot - {col}' if col == 'sepal length' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %% [markdown]
# ### Interpretasi Insight

# %% [markdown]
# Dari beberapa interpretasi yang telah dilakukan, sepal width dan petal length memiliki hasil yang lebih baih dari pada yang lainnya

# %% [markdown]
# ## 2. Assignment Feature Engineering
# 2. Outlier Handling (Silahkan bisa dilakukan bisa tidak, cantumkan alasan saudara jika menggunakan teknik outlier handling)
# 3. Feature Scalling (Pilih salah satu : MinMaxScaller atau Standar Scaller)

# %%
#Tambahkan cell jika perlu

# %%
print(df.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
fitur_columns = ['sepal width (cm)', 'petal length (cm)']
X = df[fitur_columns].values
y = df['species'].values #anotator label

# %%
# Feature Scalling
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)
df_scalling = pd.DataFrame(data = X_std, columns = fitur_columns )
df_scalling.describe()
# Out:
#        sepal width (cm)  petal length (cm)
# count      1.490000e+02       1.490000e+02
# mean       1.669060e-16      -1.430623e-16
# std        1.003373e+00       1.003373e+00
# min       -2.436862e+00      -1.560289e+00
# 25%       -5.972549e-01      -1.219738e+00
# 50%       -1.373532e-01       3.127435e-01
# 75%        5.524994e-01       7.668121e-01
# max        3.081959e+00       1.788466e+00

# %%
X_std
# Out:
# array([[ 1.01240113, -1.33325507],
#        [-0.1373532 , -1.33325507],
#        [ 0.32254853, -1.39001364],
#        [ 0.09259766, -1.2764965 ],
#        [ 1.242352  , -1.33325507],
#        [ 1.9322046 , -1.16297935],
#        [ 0.78245027, -1.33325507],
#        [ 0.78245027, -1.2764965 ],
#        [-0.36730407, -1.33325507],
#        [ 0.09259766, -1.2764965 ],
#        [ 1.47230287, -1.2764965 ],
#        [ 0.78245027, -1.21973792],
#        [-0.1373532 , -1.33325507],
#        [-0.1373532 , -1.50353079],
#        [ 2.16215547, -1.44677222],
#        [ 3.08195894, -1.2764965 ],
#        [ 1.9322046 , -1.39001364],
#        [ 1.01240113, -1.33325507],
#        [ 1.70225374, -1.16297935],
#        [ 1.70225374, -1.2764965 ],
#        [ 0.78245027, -1.16297935],
#        [ 1.47230287, -1.2764965 ],
#        [ 1.242352  , -1.56028936],
#        [ 0.5524994 , -1.16297935],
#        [ 0.78245027, -1.0494622 ],
#        [-0.1373532 , -1.21973792],
#        [ 0.78245027, -1.21973792],
# ...

# %%
df_scalling
# Out:
#      sepal width (cm)  petal length (cm)
# 0            1.012401          -1.333255
# 1           -0.137353          -1.333255
# 2            0.322549          -1.390014
# 3            0.092598          -1.276496
# 4            1.242352          -1.333255
# ..                ...                ...
# 144         -0.137353           0.823571
# 145         -1.287108           0.710054
# 146         -0.137353           0.823571
# 147          0.782450           0.937088
# 148         -0.137353           0.766812
#
# [149 rows x 2 columns]

# %% [markdown]
# ## 3. Assignment K-Means
# 1. Elbow Method
# 2. Via Score Plot
# 3. Evaluasi model
# ### 1. Elbow Method

# %%
#Tambahkan cell jika perlu

# %%
from sklearn.cluster import KMeans
inertia = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df_scalling.values)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(20, 10))

sns.lineplot(x=range(1, 11), y=inertia, color='#000087', linewidth = 4)
sns.scatterplot(x=range(1, 11), y=inertia, s=300, color='#800000',  linestyle='--')
plt.title('Elbow Method - Finding K value Clusters')
plt.xlabel('The Amount of K')
plt.ylabel('Intertia / WSS')
# Out:
# Text(0, 0.5, 'Intertia / WSS')

# %%
#Dari hasil diatas elbow nya dipilih pada angka 4,
# karena titik awal sebelum titik selanjutnya memiliki gap yang konstan atau
# titik setelah lekukan tajam sebelum mendatar
from sklearn.cluster import KMeans
kmeans_elbow = KMeans(n_clusters=4, random_state=0)
kmeans_elbow.fit(df_scalling.values)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
#taruh hasil k-means elbow method ke df dengan nama kolom cluster_elbow
df['cluster_elbow'] = kmeans_elbow.labels_

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species  cluster_elbow  cluster_via
# 0  setosa              3            1
# 1  setosa              3            1
# 2  setosa              3            1
# 3  setosa              3            1
# 4  setosa              1            1

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal width (cm)', y='petal length (cm)', hue='cluster_elbow')
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>

# %%
# Dibandingkan dengan hasil label anotator
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal width (cm)', y='petal length (cm)',hue='species')
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>

# %% [markdown]
# ### Interpretasi dan Hasil Evaluasi

# %% [markdown]
# Dari hasil ditas menunjukkan bahwa menggunakan elbow tidak optimal karena cluster yang dihasilkan berbeda dengan label anotator

# %% [markdown]
# ### 2. Via Score Plot

# %%
#Tambahkan cell jika perlu

# %%
# !pip install yellowbrick

# %%
# Via Score Plot
from yellowbrick.cluster import KElbowVisualizer
k_means_via = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(k_means_via, k=(1,11), timings= True)
visualizer.fit(df_scalling.values)        # Fit the data to the visualizer
plt.title('Distortion Via-Score Plot for K-Means Clustering')
plt.show()

# %%
# Dari hasil diatas K-nya dipilih pada angka 3,
# karena titik distorsinya bertemu pada nilai 3 di sumbu x
from sklearn.cluster import KMeans
kmeans_via = KMeans(n_clusters=3, random_state=0)
kmeans_via.fit(df_scalling.values)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
#taruh hasil k-means via score method ke df dengan nama kolom cluster_via
df['cluster_via'] = kmeans_via.labels_

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 144                6.7               3.0                5.2               2.3
# 145                6.3               2.5                5.0               1.9
# 146                6.5               3.0                5.2               2.0
# 147                6.2               3.4                5.4               2.3
# 148                5.9               3.0                5.1               1.8
#
# ...

# %%
#Lakukan evaluasi setelah dilakukan K-Means
#Bandingkan hasil cluster dengan distribusi data asli
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal width (cm)', y='petal length (cm)', hue='cluster_via')
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>

# %%
# Bandingkan dengan anotator
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='sepal width (cm)', y='petal length (cm)',hue='species')
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>

# %% [markdown]
# ### Interpretasi dan Hasil Evaluasi

# %% [markdown]
# Dari hasil diatas menunjukkan bahwa clustering dengan menggunakan via score plot adalah tidak optimal. Hasil yang ditunjukkan tidak sama dengan anotator

# %% [markdown]
# ## 4. Assignment Multiclass
# 1. gunakan : Logistic Regression, Naive Bayes, KNN, SVM atau model AI-machine learning lainnya
# 2. Evaluasi model

# %%
#Tambahkan cell jika perlu

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species  cluster_elbow  cluster_via
# 0  setosa              3            1
# 1  setosa              3            1
# 2  setosa              3            1
# 3  setosa              3            1
# 4  setosa              1            1

# %%
df.cluster_elbow.value_counts(normalize=True)
#balances
# Out:
# 0    0.449664
# 3    0.221477
# 2    0.221477
# 1    0.107383
# Name: cluster_elbow, dtype: float64

# %%
df_multi = df[['sepal width (cm)','petal length (cm)','species','cluster_elbow']]
df_multi.head()
# Out:
#    sepal width (cm)  petal length (cm) species  cluster_elbow
# 0               3.5                1.4  setosa              3
# 1               3.0                1.4  setosa              3
# 2               3.2                1.3  setosa              3
# 3               3.1                1.5  setosa              3
# 4               3.6                1.4  setosa              1

# %%
# Splitting feature engineering Supervised

from sklearn.model_selection import train_test_split
train, test = train_test_split(df_multi, test_size = 0.25, random_state = 42, stratify=df_multi.cluster_elbow)

# %%
train.head()
# Out:
#      sepal width (cm)  petal length (cm)     species  cluster_elbow
# 109               3.6                6.1   virginica              0
# 148               3.0                5.1   virginica              0
# 95                3.0                4.2  versicolor              0
# 51                3.2                4.5  versicolor              0
# 71                2.8                4.0  versicolor              2

# %%
test.head()
# Out:
#      sepal width (cm)  petal length (cm)     species  cluster_elbow
# 88                3.0                4.1  versicolor              0
# 46                3.8                1.6      setosa              1
# 116               3.0                5.5   virginica              0
# 85                3.4                4.5  versicolor              0
# 91                3.0                4.6  versicolor              0

# %%
#label predictor (X)
X_train = train[['petal length (cm)','sepal width (cm)']]
X_test = test[['petal length (cm)','sepal width (cm)']]

#label target
y_train = train[['cluster_elbow']]
y_test = test[['cluster_elbow']]

# %%
#import model classification for multiclass
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn.svm import SVC #SVM
from sklearn.naive_bayes import GaussianNB #Naive Bayes
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.metrics import accuracy_score, classification_report #Evaluation matrix

# %% [markdown]
# ## LR

# %%
# Logistic Regression
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train.values.ravel())
lr_pred_train = lr_model.predict(X_train)
lr_pred_test = lr_model.predict(X_test)

# Evaluasi model
print("Logistic Regression:")
print("Accuracy train:", accuracy_score(y_train, lr_pred_train))
print("Accuracy test:", accuracy_score(y_test, lr_pred_test))
print(classification_report(y_test, lr_pred_test))
#Akurasi yang muncul ialah akurasi dari rata-rata terhadap semua label multiclass classification
# Out:
# Logistic Regression:
# Accuracy train: 0.9009009009009009
# Accuracy test: 0.9210526315789473
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        17
#            1       1.00      0.75      0.86         4
#            2       1.00      0.78      0.88         9
#            3       0.89      1.00      0.94         8
#
#     accuracy                           0.92        38
#    macro avg       0.95      0.88      0.90        38
# weighted avg       0.93      0.92      0.92        38

# %% [markdown]
# ## SVM

# %%
# SVM
svm_model = SVC(kernel='linear', random_state=42)
svm_model.fit(X_train, y_train.values.ravel())
svm_pred_train = svm_model.predict(X_train)
svm_pred_test = svm_model.predict(X_test)

# %%
# Evaluasi model
print("SVM:")
print("Accuracy train:", accuracy_score(y_train, svm_pred_train))
print("Accuracy test:", accuracy_score(y_test, svm_pred_test))
print(classification_report(y_test, svm_pred_test))
#Akurasi yang muncul ialah akurasi dari rata-rata terhadap semua label multiclass classification
# Out:
# SVM:
# Accuracy train: 0.8828828828828829
# Accuracy test: 0.8947368421052632
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        17
#            1       1.00      0.75      0.86         4
#            2       1.00      0.67      0.80         9
#            3       0.89      1.00      0.94         8
#
#     accuracy                           0.89        38
#    macro avg       0.93      0.85      0.88        38
# weighted avg       0.91      0.89      0.89        38

# %% [markdown]
# ## Naive Bayes

# %%
# Naive Bayes
nb_model = GaussianNB()
nb_model.fit(X_train, y_train.values.ravel())
nb_pred_train = nb_model.predict(X_train)
nb_pred_test = nb_model.predict(X_test)

# %%
print("\nNaive Bayes:")
print("Accuracy train:", accuracy_score(y_train, nb_pred_train))
print("Accuracy test:", accuracy_score(y_test, nb_pred_test))
print(classification_report(y_test, nb_pred_test))
#Akurasi yang muncul ialah akurasi dari rata-rata terhadap semua label multiclass classification
# Out:
# Naive Bayes:
# Accuracy train: 0.963963963963964
# Accuracy test: 0.9210526315789473
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        17
#            1       1.00      1.00      1.00         4
#            2       1.00      0.67      0.80         9
#            3       1.00      1.00      1.00         8
#
#     accuracy                           0.92        38
#    macro avg       0.96      0.92      0.93        38
# weighted avg       0.93      0.92      0.92        38

# %% [markdown]
# ## KNN

# %%
# KNN
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train.values.ravel())
knn_pred_train = knn_model.predict(X_train)
knn_pred_test = knn_model.predict(X_test)

# %%
print("KNN:")
print("Accuracy train:", accuracy_score(y_train, knn_pred_train))
print("Accuracy test:", accuracy_score(y_test, knn_pred_test))
print(classification_report(y_test, knn_pred_test))
#Akurasi yang muncul ialah akurasi dari rata-rata terhadap semua label multiclass classification
# Out:
# KNN:
# Accuracy train: 0.9369369369369369
# Accuracy test: 0.9473684210526315
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        17
#            1       1.00      0.75      0.86         4
#            2       1.00      0.89      0.94         9
#            3       0.89      1.00      0.94         8
#
#     accuracy                           0.95        38
#    macro avg       0.96      0.91      0.93        38
# weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# ## 5. Tulis Interpretasi dan Insight di tiap model + evaluasi model dan EDA dengan alasan kalian.

# %% [markdown]
# Berdasarkan evaluasi model yang telah didapatkan, naive bayes memiliki selisih akurasi antara train dan test lebih besar dari pada yang lainnya. Selain itu hasil naive bayes juga memiliki hasil akurasi tertinggi dibandign dengan mmodel lainnya.
#
# Kemudian, dari ketiga model lainnya yang memiliki nilai akurasi tertinggi dengan selisih antara train dan test hanya sekitar 0.01 yaitu KNN

# %% [markdown]
# ## Melihat hasil prediksi NB dengan label anotator

# %%
#Tambahkan cell jika perlu

# %%
df_multi.head()
# Out:
#    sepal width (cm)  petal length (cm) species  cluster_elbow
# 0               3.5                1.4  setosa              3
# 1               3.0                1.4  setosa              3
# 2               3.2                1.3  setosa              3
# 3               3.1                1.5  setosa              3
# 4               3.6                1.4  setosa              1

# %%
test.head()
# Out:
#      sepal width (cm)  petal length (cm)     species  cluster_elbow
# 88                3.0                4.1  versicolor              0
# 46                3.8                1.6      setosa              1
# 116               3.0                5.5   virginica              0
# 85                3.4                4.5  versicolor              0
# 91                3.0                4.6  versicolor              0

# %%
nb_pred_test
# Out:
# array([0, 1, 0, 0, 0, 0, 3, 3, 3, 3, 2, 2, 2, 1, 0, 0, 0, 0, 0, 0, 3, 1,
#        3, 0, 3, 1, 0, 2, 0, 2, 0, 3, 0, 0, 0, 0, 2, 0], dtype=int32)

# %%
# Jika nb_pred_test merupakan numpy array, Anda dapat mengonversinya ke DataFrame seperti ini:
nb_pred_test_df = pd.DataFrame(data=nb_pred_test, columns=['prediksi_ml'])
nb_pred_test_df
# Out:
#     prediksi_ml
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0
# 5             0
# 6             3
# 7             3
# 8             3
# 9             3
# 10            2
# 11            2
# 12            2
# 13            1
# 14            0
# 15            0
# 16            0
# 17            0
# 18            0
# 19            0
# 20            3
# 21            1
# 22            3
# 23            0
# 24            3
# 25            1
# 26            0
# 27            2
# 28            0
# 29            2
# 30            0
# 31            3
# 32            0
# 33            0
# 34            0
# 35            0
# 36            2
# 37            0

# %%
# Reset index pada DataFrame test
test_reset_index = test.reset_index(drop=True)

# Concatenate DataFrame prediksi_ml dengan DataFrame test yang telah di-reset index
test = pd.concat([test_reset_index, nb_pred_test_df], axis=1)
test.head()
# Out:
#    sepal width (cm)  petal length (cm)     species  cluster_elbow  prediksi_ml
# 0               3.0                4.1  versicolor              0            0
# 1               3.8                1.6      setosa              1            1
# 2               3.0                5.5   virginica              0            0
# 3               3.4                4.5  versicolor              0            0
# 4               3.0                4.6  versicolor              0            0

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=test, x='sepal width (cm)', y='petal length (cm)', hue='prediksi_ml')
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=test, x='sepal width (cm)', y='petal length (cm)', hue='species')
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>

# %%
test
# Out:
#     sepal width (cm)  petal length (cm)     species  cluster_elbow  \
# 0                3.0                4.1  versicolor              0
# 1                3.8                1.6      setosa              1
# 2                3.0                5.5   virginica              0
# 3                3.4                4.5  versicolor              0
# 4                3.0                4.6  versicolor              0
# 5                3.1                5.1   virginica              0
# 6                3.2                1.2      setosa              3
# 7                3.1                1.5      setosa              3
# 8                3.5                1.6      setosa              3
# 9                3.2                1.3      setosa              3
# 10               2.3                3.3  versicolor              2
# 11               2.5                4.0  versicolor              2
# 12               2.4                3.8  versicolor              2
# ...

# %% [markdown]
# Berdasarkan hasil yang didaptkan, naive bayes juga belum dapat melakukan clustering dengan optimal, dapat dilihat dari hasil perbandingan dengan anotator. Walaupun sama menunjukkan bahwa dapat mengcluster 4 kategori, namun masih terdapat beberapa node yang memiliki kategori yang berbeda
